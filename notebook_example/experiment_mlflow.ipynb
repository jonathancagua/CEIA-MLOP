# %%
import awswrangler as wr

import mlflow

# Para que funciones, todos nuestros scripts debemos exportar las siguientes variables de entorno
# %env AWS_ACCESS_KEY_ID=minio   
# %env AWS_SECRET_ACCESS_KEY=minio123 
# %env MLFLOW_S3_ENDPOINT_URL=http://localhost:9008
# %env AWS_ENDPOINT_URL_S3=http://localhost:9008
#%env MLFLOW_S3_ENDPOINT_URL=http://192.168.0.21:9000
#%env AWS_ENDPOINT_URL_S3=http://192.168.0.21:9000
# Out:
# env: AWS_ACCESS_KEY_ID=minio
# env: AWS_SECRET_ACCESS_KEY=minio123
# env: MLFLOW_S3_ENDPOINT_URL=http://localhost:9008
# env: AWS_ENDPOINT_URL_S3=http://localhost:9008

# %% [markdown]
# # Búsqueda de mejor modelo e hiperparámetros
#
# Dado nuestro dataset de Heart Disease, el cual ya pasó por el proceso de ETL y se encuentra en nuestro S3 bucket, vamos a realizar una búsqueda de cual seria el mejor modelo y que hiperparametros usar.
#
# La búsqueda de hiperparametros la haremos usando Optuna y el tracking será realizado mediante MLFlow.
#
# OBS: Para la confección de esta notebook, nos basamos en el tutorial de [MLFlow](https://mlflow.org/docs/latest/traditional-ml/hyperparameter-tuning-with-child-runs/notebooks/index.html).

# %%
mlflow_server = "http://localhost:5006"
#mlflow_server = "http://192.168.0.21:5000"

mlflow.set_tracking_uri(mlflow_server)

# %%
try:
    X_train =  wr.s3.read_csv("s3://data/final/train/spotify_X_train.csv")
    y_train =  wr.s3.read_csv("s3://data/final/train/spotify_y_train.csv")

    X_test =  wr.s3.read_csv("s3://data/final/test/spotify_X_test.csv")
    y_test =  wr.s3.read_csv("s3://data/final/test/spotify_y_test.csv")
except wr.exceptions.NoFilesFound as e:
    print(f"Error detectado: {e}")
    print("Ejecuta Airflow el DAG de ETL")

# %%
print(X_test.head())
# Out:
#    speechiness  energy  danceability  acousticness
# 0       0.2450   0.750         0.710       0.64800
# 1       0.2710   0.769         0.818       0.01440
# 2       0.1200   0.559         0.884       0.02360
# 3       0.0679   0.635         0.599       0.06400
# 4       0.0299   0.854         0.547       0.00347

# %% [markdown]
# ## Investigamos la correlación de features con la variable objetivo
#
# Antes de profundizar en el proceso de construcción de modelo, es esencial comprender las relaciones entre nuestras features  y la variable objetivo. Por lo que vamos a realizar un gráfico que indica el coeficiente de correlación de cada feature en relación con la variable objetivo. Esto nos sirve para:
#
# - Evitar data leakage: Debemos asegurarnos de que ninguna característica se correlacione perfectamente con el objetivo (un coeficiente de correlación de aproximadamente 1.0). Si existe tal correlación, es una señal de que nuestro conjunto de datos podría estar "filtrando" información sobre el objetivo.
#
# - Garantizar relaciones significativas: Idealmente, nuestras características deberían tener algún grado de correlación con el objetivo. Inclusive si estamos trabajando con un problema de clasificación, aunque los resultados no son tan importantes como en un caso de regresión.
#
# - Auditoría y trazabilidad: Loggear esta visualización de correlación con nuestra ejecución principal de MLflow garantiza la trazabilidad. Proporciona una instantánea de las características de los datos en el momento del entrenamiento del modelo, lo cual es invaluable para propósitos de auditoría y replicabilidad.

# %%
from plots import plot_correlation_with_target, plot_information_gain_with_target

# %%
# Dado que estamos usando como tracking a MLFlow, mostrar los gráficos aquí no tiene sentido.
correlation_plot = plot_correlation_with_target(X_train, y_train)
information_gain_plot = plot_information_gain_with_target(X_train, y_train)

# %% [markdown]
# ## Arrancamos a experimentar

# %%
import datetime
import optuna

from mlflow.models import infer_signature
from mlflow_aux import get_or_create_experiment

from optuna_aux import champion_callback, objective

from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# Optuna es un poco verboso, dejamos que solo nos muestre logs de errores
optuna.logging.set_verbosity(optuna.logging.ERROR)

# %% [markdown]
# Antes de poder realizar experimentos, vamos a crear el experimento en MLFLow, pero para evitar desorden, vamos a usar una función que se fije primero si el experimento existe, si esto es así, devuelve su ID.
#
# Además creamos el nombre del run padre con el que vamos a ir registrando las ejecuciones.

# %%
# Creemos el experimento
experiment_id = get_or_create_experiment("Spotify")
print(experiment_id)

run_name_parent = "best_hyperparam_"  + datetime.datetime.today().strftime('%Y/%m/%d-%H:%M:%S"')
# Out:
# 2

# %% [markdown]
# Ya con todo seteado, vamos a ejecutar la optimización usando Optuna, el cual realiza una búsqueda Bayesiana, la cual es más eficiente que una búsqueda de grilla tradicional. La desventaja es que es más difícil de paralelizar.

# %%
import optuna
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
import mlflow
from mlflow.models import infer_signature


with mlflow.start_run(experiment_id=experiment_id, run_name=run_name_parent, nested=True):
    # Inicializamos el estudio de Optuna
    study = optuna.create_study(direction="maximize")

    # Ejecutamos los trials de optimización de hiperparámetros
    study.optimize(
        lambda trial: objective(trial, X_train, y_train, experiment_id),
        n_trials=250,
        callbacks=[champion_callback]
    )

    # Logueamos los mejores parámetros y el mejor valor de f1 en el run padre
    mlflow.log_params(study.best_params)
    mlflow.log_metric("best_train_f1", study.best_value)

    mlflow.set_tags(
        tags={
            "project": "Spotify",
            "optimizer_engine": "optuna",
            "model_family": "sklearn_xgboost",
            "feature_set_version": 1,
        }
    )

    # Selección del modelo basado en los mejores parámetros
    model = None  # Inicializamos `model` como None por defecto

    if study.best_params["classifier"] == "LogisticRegression":
        model = LogisticRegression(
            C=study.best_params["logreg_c"],
            solver='liblinear'
        )
    elif study.best_params["classifier"] == "XGBoost":
        model = XGBClassifier(
            max_depth=study.best_params["xgb_max_depth"],
            n_estimators=study.best_params["xgb_n_estimators"],
            learning_rate=study.best_params["xgb_learning_rate"]
        )
    elif study.best_params["classifier"] == "SVC_linear":
        model = SVC(
            C=study.best_params["svc_c"],
            kernel='linear',
            gamma='scale'
        )
    elif study.best_params["classifier"] == "SVC_poly":
        model = SVC(
            C=study.best_params["svc_c"],
            kernel='poly',
            degree=study.best_params["svc_poly_degree"],
            gamma='scale'
        )
    elif study.best_params["classifier"] == "SVC_rbf":
        model = SVC(
            C=study.best_params["svc_c"],
            kernel='rbf',
            gamma='scale'
        )
    elif study.best_params["classifier"] == "DecisionTreeClassifier":
        model = DecisionTreeClassifier(
            max_depth=study.best_params["tree_max_depth"]
        )
    elif study.best_params["classifier"] == "RandomForest":
        model = RandomForestClassifier(
            max_depth=study.best_params["rf_max_depth"],
            n_estimators=study.best_params["rf_n_estimators"]
        )

    # Verificamos que el modelo fue definido
    if model is not None:
        # Entrenamiento del modelo
        model = model.fit(X_train, y_train.to_numpy().ravel())

        # Predicción y evaluación del modelo
        y_pred = model.predict(X_test)
        test_f1 = f1_score(y_test.to_numpy().ravel(), y_pred)
        mlflow.log_metric("test_f1", test_f1)

        # Logueo del modelo como artefacto
        artifact_path = "model"
        signature = infer_signature(X_train, model.predict(X_train))

        mlflow.sklearn.log_model(
            sk_model=model,
            artifact_path=artifact_path,
            signature=signature,
            serialization_format='cloudpickle',
            registered_model_name="spotify_model_dev",
            metadata={"model_data_version": 1}
        )

        # Obtenemos la ubicación del modelo guardado en MLFlow
        model_uri = mlflow.get_artifact_uri(artifact_path)
        print(f"Modelo registrado en MLFlow: {model_uri}")
    else:
        print("No se definió un modelo válido.")
# Out:
# 🏃 View run Trial: 0 at: http://localhost:5006/#/experiments/2/runs/48af400835944ef6a3463433fb725811
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# Initial trial 0 achieved value: 0.8653736622169713
# 🏃 View run Trial: 1 at: http://localhost:5006/#/experiments/2/runs/2c06fde88750490ba30c5fe4829022ab
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 2 at: http://localhost:5006/#/experiments/2/runs/f7c787a17f8947a7b99da2dcfca39ef3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 3 at: http://localhost:5006/#/experiments/2/runs/1b301cc9bad64d089aa08d8be637d612
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 4 at: http://localhost:5006/#/experiments/2/runs/c1733a9533374c7090f29c43b389a49d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 5 at: http://localhost:5006/#/experiments/2/runs/c497f3a0e04d46a3b519d802ee223f55
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 6 at: http://localhost:5006/#/experiments/2/runs/28dc5567d2dd431fa490d9593d406ecc
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 7 at: http://localhost:5006/#/experiments/2/runs/b41863a9e67a4cd197ec4225041ab561
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 8 at: http://localhost:5006/#/experiments/2/runs/3b5aeedfb78748a9a7683b3b6d3f76d5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 9 at: http://localhost:5006/#/experiments/2/runs/d82aabf88e824be7bf56da81e87f16e6
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 10 at: http://localhost:5006/#/experiments/2/runs/320b4c34b4044e6986b1a31a6d2c0dbe
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# Trial 10 achieved value: 0.8676784706257035 with  0.2656% improvement
# 🏃 View run Trial: 11 at: http://localhost:5006/#/experiments/2/runs/3a1f52843e844dbfb23fb4e3e4dabe1d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 12 at: http://localhost:5006/#/experiments/2/runs/d7026b04e3fe48d5b0d71dbd03785eba
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 13 at: http://localhost:5006/#/experiments/2/runs/d32303a69d3d440f8c35173f374f13fa
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 14 at: http://localhost:5006/#/experiments/2/runs/415c82d2682d4595981b066c98e59dd8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# Trial 14 achieved value: 0.8695534983848046 with  0.2156% improvement
# 🏃 View run Trial: 15 at: http://localhost:5006/#/experiments/2/runs/d764d51eb3444a4a9dc3e47ab635c747
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 16 at: http://localhost:5006/#/experiments/2/runs/eef4b1e2c9b840ad862516b260c04e5e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 17 at: http://localhost:5006/#/experiments/2/runs/74099eca86cd465199430bea560a6965
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 18 at: http://localhost:5006/#/experiments/2/runs/568c68c1a846432b8c29594126648e0b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 19 at: http://localhost:5006/#/experiments/2/runs/168b0f295b2c4a12a66290e7f828c6e7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 20 at: http://localhost:5006/#/experiments/2/runs/8de162129cd24e5c929f8f2ed62a4c6e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 21 at: http://localhost:5006/#/experiments/2/runs/7940d37437b34765be1177e98bb92f59
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 22 at: http://localhost:5006/#/experiments/2/runs/2818c79bc5054b669812f8ee3cc9e208
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 23 at: http://localhost:5006/#/experiments/2/runs/f9dcd7cf70544195b416573442c6a410
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 24 at: http://localhost:5006/#/experiments/2/runs/e3fa955edcfa43fba3ea03260c83cd6d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 25 at: http://localhost:5006/#/experiments/2/runs/48ecdfc22bee4b73a73356bba180b95d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 26 at: http://localhost:5006/#/experiments/2/runs/fc472c117a8345a1b6feecf58bb8c56b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 27 at: http://localhost:5006/#/experiments/2/runs/4a8b3ecd1d864543bb4caced6cbbc8f9
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 28 at: http://localhost:5006/#/experiments/2/runs/69e9bd4be3154b61aaee1024d4832970
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 29 at: http://localhost:5006/#/experiments/2/runs/d9a07a17db9a47d3bf982ef1d42710cc
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 30 at: http://localhost:5006/#/experiments/2/runs/f659bec773f746cba5d19dc5638c7e46
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 31 at: http://localhost:5006/#/experiments/2/runs/3c344aad110c41c28d478103b866d3a3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 32 at: http://localhost:5006/#/experiments/2/runs/917e3c893f274cabad801c09399c0316
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 33 at: http://localhost:5006/#/experiments/2/runs/7e17851429f34e638ea2f5f8644ed49f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 34 at: http://localhost:5006/#/experiments/2/runs/fe75e93561d64271bf4a53d09d07b816
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 35 at: http://localhost:5006/#/experiments/2/runs/2c6094643c804f9395a8079e80718c01
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 36 at: http://localhost:5006/#/experiments/2/runs/42bc6cfce13c4f889d3cf16c5950722b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 37 at: http://localhost:5006/#/experiments/2/runs/568708df406a4ee5b0930bfc45e8921b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 38 at: http://localhost:5006/#/experiments/2/runs/69c0842475c8479b873aa920454e82cb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 39 at: http://localhost:5006/#/experiments/2/runs/c1ef5ce8ae934cb49d815f99576173bb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 40 at: http://localhost:5006/#/experiments/2/runs/0bdb28a608754fb7936f562e12ad43f1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 41 at: http://localhost:5006/#/experiments/2/runs/ed56e795ce51421e91ea82d97eb343d1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 42 at: http://localhost:5006/#/experiments/2/runs/084b824292af41bda9ae9f65d802ac77
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 43 at: http://localhost:5006/#/experiments/2/runs/25a70db05eab42de975f41a5a42fb45f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 44 at: http://localhost:5006/#/experiments/2/runs/daeac04a04a54dbabfaeb023fcb7ca5e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 45 at: http://localhost:5006/#/experiments/2/runs/6e16379c249d41d7be9945c56e5c509f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 46 at: http://localhost:5006/#/experiments/2/runs/0e2898aa2c9248debb4b7b77fd655a6c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 47 at: http://localhost:5006/#/experiments/2/runs/5e020bb6523b47b1ba90d0e84326d9e7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 48 at: http://localhost:5006/#/experiments/2/runs/3503425d480e410686fbde708ec0ddbb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 49 at: http://localhost:5006/#/experiments/2/runs/7617355afe7247c5827b9b252848d2b5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 50 at: http://localhost:5006/#/experiments/2/runs/22616061bf8d4333ac8d07fe2f1c2f83
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 51 at: http://localhost:5006/#/experiments/2/runs/796ced48519542cd8f2143a6998833a7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 52 at: http://localhost:5006/#/experiments/2/runs/4c4cc67e474f418d8aaf10c696c80bfe
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 53 at: http://localhost:5006/#/experiments/2/runs/f8b464d1c26847a5925bf488dfcc6e37
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 54 at: http://localhost:5006/#/experiments/2/runs/4ffc95b309954fb98626d044c19774e8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 55 at: http://localhost:5006/#/experiments/2/runs/6ec4af875c9e44e291f87ecf567412c3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 56 at: http://localhost:5006/#/experiments/2/runs/bb849538a6c04e8f9728674fe710c47e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 57 at: http://localhost:5006/#/experiments/2/runs/459203bcdb2f4a16b5ab935ebe5a0f07
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 58 at: http://localhost:5006/#/experiments/2/runs/fe242b48dbbb47c6affbc0f7d1a3d661
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 59 at: http://localhost:5006/#/experiments/2/runs/36eca1a754f64c79a6207f66c1803fd6
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 60 at: http://localhost:5006/#/experiments/2/runs/a5789a0c8374479a932f6cbd3bcade7a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 61 at: http://localhost:5006/#/experiments/2/runs/ea15f0a2b9e048e58054149f1015d387
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 62 at: http://localhost:5006/#/experiments/2/runs/1c6eb0e478234e1bb972e902a81a06c3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 63 at: http://localhost:5006/#/experiments/2/runs/912a0191e36249a8af969f1db8f504f0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 64 at: http://localhost:5006/#/experiments/2/runs/74ff2ba76b3e45e990425ecc4e00e2d1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 65 at: http://localhost:5006/#/experiments/2/runs/3257dae6e310462fb22eb998053fd509
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 66 at: http://localhost:5006/#/experiments/2/runs/ec6c1fb6ef15493f945b50b659319f63
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 67 at: http://localhost:5006/#/experiments/2/runs/bf721746563745d88aaf1f5e648aa760
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 68 at: http://localhost:5006/#/experiments/2/runs/6dddf6db0e704c9aac594e7fe4bef69d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 69 at: http://localhost:5006/#/experiments/2/runs/38597428185844b788295470fd5ac949
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 70 at: http://localhost:5006/#/experiments/2/runs/8b8f06be0a244685a02433a293ff94e1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 71 at: http://localhost:5006/#/experiments/2/runs/98754420eb154398a45ee8e79862c457
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 72 at: http://localhost:5006/#/experiments/2/runs/c0d6a7194cb94f578dfe19b11d1f777a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 73 at: http://localhost:5006/#/experiments/2/runs/8c2c64a0d59148dba951598fa7d428c4
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 74 at: http://localhost:5006/#/experiments/2/runs/fc064c83575543529b6eddf0df60a345
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 75 at: http://localhost:5006/#/experiments/2/runs/963683e25a5f4eb2961c0e081b5e71d7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 76 at: http://localhost:5006/#/experiments/2/runs/77ef0b16e897462b94642a618179de09
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 77 at: http://localhost:5006/#/experiments/2/runs/7716eaa8a0c04f53b21be5a85feeac88
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 78 at: http://localhost:5006/#/experiments/2/runs/392718895228494fbe5d0f8fa3f3c17e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 79 at: http://localhost:5006/#/experiments/2/runs/649d9e8eb7f1473fb00a7262493c1e05
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 80 at: http://localhost:5006/#/experiments/2/runs/e02daa394a1c457ba33db1d492f2244d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 81 at: http://localhost:5006/#/experiments/2/runs/331d863348954b65b5ec685d6a85e2c8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 82 at: http://localhost:5006/#/experiments/2/runs/83f06b244beb46c394c559a58eb5ca1f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 83 at: http://localhost:5006/#/experiments/2/runs/844d9845e08b43eeb7ee0c9c6c3454be
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 84 at: http://localhost:5006/#/experiments/2/runs/d26e407d68414664b6550bdbfe3207a0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 85 at: http://localhost:5006/#/experiments/2/runs/c79cafa1129f4eb7b41d8c78fdeb30d1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 86 at: http://localhost:5006/#/experiments/2/runs/b49d3c83cebc48fdbbbf536842c82ef5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 87 at: http://localhost:5006/#/experiments/2/runs/a7f918e86ba64d1f98f60c14beae8d68
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 88 at: http://localhost:5006/#/experiments/2/runs/6e4892f1651946a492a93e9fc15dbea0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 89 at: http://localhost:5006/#/experiments/2/runs/b31cbf019e874cd6be5c8320d8d7bde9
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 90 at: http://localhost:5006/#/experiments/2/runs/50b1107c3f934b8aaaf2aadfc99d461c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 91 at: http://localhost:5006/#/experiments/2/runs/2e4bd48ec3344fc38fdc8bbac42146c1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 92 at: http://localhost:5006/#/experiments/2/runs/ba15f7e0a6dd4ba5b58e13109074ceb8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 93 at: http://localhost:5006/#/experiments/2/runs/17d4bc9721d64c61bd39c505ba7438a3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 94 at: http://localhost:5006/#/experiments/2/runs/10d8549076f2448e9cd24458a7566b8a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 95 at: http://localhost:5006/#/experiments/2/runs/d4afcaba35fb41699bf82d22bb3afa7c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 96 at: http://localhost:5006/#/experiments/2/runs/11253d6852164ff586e628556367ec53
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 97 at: http://localhost:5006/#/experiments/2/runs/5301360b03b74da495655fba9a9c9204
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 98 at: http://localhost:5006/#/experiments/2/runs/8587427857194e5380ebc3c6bbf55f93
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 99 at: http://localhost:5006/#/experiments/2/runs/d2bbc3ebf42f4e00bc06b04ce7b70c25
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 100 at: http://localhost:5006/#/experiments/2/runs/cc32c6530e0c466d9fa920de5a1fdbd2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 101 at: http://localhost:5006/#/experiments/2/runs/9eca683aa4f2422bb098c6f5f2bd3286
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 102 at: http://localhost:5006/#/experiments/2/runs/a23f8fa9fb5a46108b4631f227d6d229
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 103 at: http://localhost:5006/#/experiments/2/runs/32ce53fa188d475eb3e516ebd7ba8c89
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 104 at: http://localhost:5006/#/experiments/2/runs/d423463d9921429c969198316a2a3be7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 105 at: http://localhost:5006/#/experiments/2/runs/e2539c44a8194d07a2a2de1596da68aa
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 106 at: http://localhost:5006/#/experiments/2/runs/3f20fea8304a403da72582f2e7a115b3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 107 at: http://localhost:5006/#/experiments/2/runs/b38b9428d74040e888df913977f2460a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 108 at: http://localhost:5006/#/experiments/2/runs/ee4a3a2d03b84385bb7eb5c339ab1ff9
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 109 at: http://localhost:5006/#/experiments/2/runs/30c65a730c364b378de86c88119a3a19
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 110 at: http://localhost:5006/#/experiments/2/runs/f659148adae6433d9eb3fb35080bcf06
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 111 at: http://localhost:5006/#/experiments/2/runs/c815ca5ea6f749298d1f8d018d40dd0b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 112 at: http://localhost:5006/#/experiments/2/runs/b1dbecb6ab4a4223b34ea432bfc67d1f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 113 at: http://localhost:5006/#/experiments/2/runs/eb5be58aee6d412ebe1bfe652f8f1e5a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 114 at: http://localhost:5006/#/experiments/2/runs/4912177cc458431bbcbbe9ed510d7139
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 115 at: http://localhost:5006/#/experiments/2/runs/6e9875428222482b90936466b780568e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 116 at: http://localhost:5006/#/experiments/2/runs/f4d557b03b59489e93f7b3bea54825d7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 117 at: http://localhost:5006/#/experiments/2/runs/b4f057569d8a45aeb971f62e165d061c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 118 at: http://localhost:5006/#/experiments/2/runs/68bd7c0a3a0b4332802c6504d1f0ce15
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 119 at: http://localhost:5006/#/experiments/2/runs/bff9a15ab5a54814b9b22ecfc0ec3666
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 120 at: http://localhost:5006/#/experiments/2/runs/aa02aa7c148e41cea6d99e155b2f1f2a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 121 at: http://localhost:5006/#/experiments/2/runs/6a416e9ef2a44efda3feccd3fd7a8b92
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 122 at: http://localhost:5006/#/experiments/2/runs/101712eb54884efa89a67d998e4fd941
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 123 at: http://localhost:5006/#/experiments/2/runs/bfd9d92329174e8daa3163205fb1e12d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 124 at: http://localhost:5006/#/experiments/2/runs/e4f89b12ecb24851be71b75abeaa8635
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 125 at: http://localhost:5006/#/experiments/2/runs/616eb6ab94034d19a78e5e049c9d8d21
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 126 at: http://localhost:5006/#/experiments/2/runs/e6f64576253e488a90af11f360f7d632
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 127 at: http://localhost:5006/#/experiments/2/runs/dd69cfefa4494fdaa8400283006ee028
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 128 at: http://localhost:5006/#/experiments/2/runs/5cee01a02585476abad8b602084fc713
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 129 at: http://localhost:5006/#/experiments/2/runs/5707173e738b4968bf75b0eabb593afb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 130 at: http://localhost:5006/#/experiments/2/runs/94726a697aa44eb080cc23859e29e62b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 131 at: http://localhost:5006/#/experiments/2/runs/7e6911a05bbc48a9934fce8c27601bd8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 132 at: http://localhost:5006/#/experiments/2/runs/b9beee22077d47d782e2f870bd9007f0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 133 at: http://localhost:5006/#/experiments/2/runs/a8d50e6a422a4dc294fe97d3bdaa14bf
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 134 at: http://localhost:5006/#/experiments/2/runs/a131f0a4ed2e4267981e3bdb6604d0ce
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 135 at: http://localhost:5006/#/experiments/2/runs/52858045d53b4980b0ed0230845303a2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 136 at: http://localhost:5006/#/experiments/2/runs/c617032ca31c496982d2fff1192dcba2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 137 at: http://localhost:5006/#/experiments/2/runs/071622f7167d4a3bbd4b60d5f618a2dd
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 138 at: http://localhost:5006/#/experiments/2/runs/993b3942e61649fabec2247c41c0ae1e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 139 at: http://localhost:5006/#/experiments/2/runs/67a635e7851d454c89cb2d9fec570e21
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 140 at: http://localhost:5006/#/experiments/2/runs/16852fca1ff3490d8e8c60a7f695292b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 141 at: http://localhost:5006/#/experiments/2/runs/9f6cacc9aa7642bc88d109ce27cff773
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 142 at: http://localhost:5006/#/experiments/2/runs/828ee76624c64f47b7a2f4e88f92077d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 143 at: http://localhost:5006/#/experiments/2/runs/223efca14c3d4c688cac427639c79de4
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 144 at: http://localhost:5006/#/experiments/2/runs/f613ba92aa4449f2bc6d7e140e76bc5c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 145 at: http://localhost:5006/#/experiments/2/runs/d277224a75df44b4b6714c2d2abdd980
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 146 at: http://localhost:5006/#/experiments/2/runs/08435192be3f415fa3843bb5ea07840c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 147 at: http://localhost:5006/#/experiments/2/runs/cee657a039d04b0c91274f7eb9b21a13
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 148 at: http://localhost:5006/#/experiments/2/runs/5b23c6558b774a8486293b9a6eae5827
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 149 at: http://localhost:5006/#/experiments/2/runs/ce62fe539c2c4fa68f124230861c29fc
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 150 at: http://localhost:5006/#/experiments/2/runs/0d2718016bf243c3b87d651945bbee9b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 151 at: http://localhost:5006/#/experiments/2/runs/4037d7ba16514c1d996112e506233fdb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 152 at: http://localhost:5006/#/experiments/2/runs/a91964b0780f44cf89a711b29579ebf0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 153 at: http://localhost:5006/#/experiments/2/runs/0b4c0d3f4954427c86cded33db4231ba
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 154 at: http://localhost:5006/#/experiments/2/runs/8978a59921df4736aa87f690d8503622
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 155 at: http://localhost:5006/#/experiments/2/runs/9bff4debe2b847449394ac9c4d67f3ae
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 156 at: http://localhost:5006/#/experiments/2/runs/e5b2adde5a2d4c04bdf13bed8e2b5eea
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 157 at: http://localhost:5006/#/experiments/2/runs/983833fb3e744056af27385ae70ae1fa
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 158 at: http://localhost:5006/#/experiments/2/runs/804d5884c1e74d9fb4e53925d1c08364
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 159 at: http://localhost:5006/#/experiments/2/runs/49858cb555ff4eeea3b524f466c89225
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 160 at: http://localhost:5006/#/experiments/2/runs/51c1e89dee284e9188e3dba00d113cd2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 161 at: http://localhost:5006/#/experiments/2/runs/177ac87018534e94bc30fc75027b2472
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 162 at: http://localhost:5006/#/experiments/2/runs/fcb447a737c546f3952373f93a6a669c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 163 at: http://localhost:5006/#/experiments/2/runs/29d1766a1e8545daa4310058508f780e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 164 at: http://localhost:5006/#/experiments/2/runs/af1ef6d2ef054be8bc40903e436a9ea7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 165 at: http://localhost:5006/#/experiments/2/runs/4df2d94caf3e416b917cc059e0999049
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 166 at: http://localhost:5006/#/experiments/2/runs/5b59f580b0d14b39951dd7a136ba1049
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 167 at: http://localhost:5006/#/experiments/2/runs/8ca7d815bd434c888c174b6ef28a9568
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 168 at: http://localhost:5006/#/experiments/2/runs/2ccddc319db94170b3d02037fc24dfe7
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 169 at: http://localhost:5006/#/experiments/2/runs/d42d720155fa4b1f8840d1dd73fb3339
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 170 at: http://localhost:5006/#/experiments/2/runs/88e51e51dde04a14b50c0a455125954e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 171 at: http://localhost:5006/#/experiments/2/runs/379c975b22bf4fb1be742dde4c4d8888
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 172 at: http://localhost:5006/#/experiments/2/runs/22577e6de7574ca99eebf9fc593a52b2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 173 at: http://localhost:5006/#/experiments/2/runs/df3ad10827334361b46f3776cb66ac3e
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 174 at: http://localhost:5006/#/experiments/2/runs/b363430c0eb64bee9e75482c1a11a510
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 175 at: http://localhost:5006/#/experiments/2/runs/9b287978c5794b5f8bda5d9545acd2a4
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 176 at: http://localhost:5006/#/experiments/2/runs/114641d2861c4bc2a7acf37ca50dfb18
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 177 at: http://localhost:5006/#/experiments/2/runs/a8350307b2f14e25b90d2b21688346e2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 178 at: http://localhost:5006/#/experiments/2/runs/5a86e831ae66430c976c94186c3c644a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 179 at: http://localhost:5006/#/experiments/2/runs/7d30f085d45e4b3f97d852357ce48cb2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 180 at: http://localhost:5006/#/experiments/2/runs/17f66b9731084e62ac1a50a84b068c5f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 181 at: http://localhost:5006/#/experiments/2/runs/e1969b2dfda54a97a1e59f806e50a6fb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 182 at: http://localhost:5006/#/experiments/2/runs/f838795727924bbda3a185b27c83bbb8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 183 at: http://localhost:5006/#/experiments/2/runs/99db40d5fc944a98901240c44eb7f6e4
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 184 at: http://localhost:5006/#/experiments/2/runs/4c1287ae32b84ef38b310fe3ca98fe1a
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 185 at: http://localhost:5006/#/experiments/2/runs/5ea1919d032d4cd9a1e2c1c481020244
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 186 at: http://localhost:5006/#/experiments/2/runs/dd7d0956aa5a4d3a8ef3a247165d6e3c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 187 at: http://localhost:5006/#/experiments/2/runs/9ea5ed5406394f6fa0ff753a07b9827c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 188 at: http://localhost:5006/#/experiments/2/runs/fc35075241ab45e1bea73a4c0764178b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 189 at: http://localhost:5006/#/experiments/2/runs/82eab9f22ba3411395a41f37c9146b75
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 190 at: http://localhost:5006/#/experiments/2/runs/bdf2257986ee481db0839d418a52b450
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 191 at: http://localhost:5006/#/experiments/2/runs/71f0cc5322f64962ad6959591d767102
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 192 at: http://localhost:5006/#/experiments/2/runs/5c3784e3b8694d928ed69977053fdef0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 193 at: http://localhost:5006/#/experiments/2/runs/1ccda45d10374de189d53a8d3246399c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 194 at: http://localhost:5006/#/experiments/2/runs/f79afdc6fe7e4eb5a94684b03eca8563
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 195 at: http://localhost:5006/#/experiments/2/runs/4b9092137c2241549c5336bd6030eb52
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 196 at: http://localhost:5006/#/experiments/2/runs/a53ea102de124910b328a21f537b2956
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 197 at: http://localhost:5006/#/experiments/2/runs/758cec4632f4488ea814e2065c0939c5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 198 at: http://localhost:5006/#/experiments/2/runs/441715b89c204d07b095435aa8573502
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 199 at: http://localhost:5006/#/experiments/2/runs/bb084006308c4a40b2ca04f846d42f74
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 200 at: http://localhost:5006/#/experiments/2/runs/219df79d2ea24af29b82c6700e03a6cb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 201 at: http://localhost:5006/#/experiments/2/runs/81842e6b18734b1f8ee517d6d7b7a401
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 202 at: http://localhost:5006/#/experiments/2/runs/8f5d37f9fc9b49938b74648dea9130bd
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 203 at: http://localhost:5006/#/experiments/2/runs/49808fd5dc93414ea834e2d57b55ef36
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 204 at: http://localhost:5006/#/experiments/2/runs/e04be80f58b8477d85726e9490fe6430
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 205 at: http://localhost:5006/#/experiments/2/runs/0fd60e684e2241a0932ca18e0f2a9273
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 206 at: http://localhost:5006/#/experiments/2/runs/c03c37010fd044df9add76978bc9ccff
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 207 at: http://localhost:5006/#/experiments/2/runs/a988429051d143bcaf2eeb1fd8f97a65
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 208 at: http://localhost:5006/#/experiments/2/runs/d534703aa9844723bc61fd01790563ad
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 209 at: http://localhost:5006/#/experiments/2/runs/ccf8c5de4c624e69a5186a7a1e910d98
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 210 at: http://localhost:5006/#/experiments/2/runs/91f2536dc73b4c46a067f2acccd56cf1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 211 at: http://localhost:5006/#/experiments/2/runs/a0bef1d9f4b74ccfb1701772acce52a2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 212 at: http://localhost:5006/#/experiments/2/runs/e5fc1ea5e20148558a3aef93eefe8664
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 213 at: http://localhost:5006/#/experiments/2/runs/a544b1757dfa4143bb0885470f5e874d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 214 at: http://localhost:5006/#/experiments/2/runs/c479a8df6e10454ab24d351a080ad1eb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 215 at: http://localhost:5006/#/experiments/2/runs/a34e7b941d82413e8a0d424ceaf0f55c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 216 at: http://localhost:5006/#/experiments/2/runs/df175c651cbe4a9a8e9958a123e78fad
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 217 at: http://localhost:5006/#/experiments/2/runs/4df04d42aa67422789aeba1b59eea2b5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 218 at: http://localhost:5006/#/experiments/2/runs/2f14c359c4964b058816f6bdbf70752b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 219 at: http://localhost:5006/#/experiments/2/runs/1771c39ef1264486969075d55153bb2c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 220 at: http://localhost:5006/#/experiments/2/runs/025c0e482dab49abb62455d9c5e662a2
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 221 at: http://localhost:5006/#/experiments/2/runs/ad898fc532d44f5c874ea78849292e50
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 222 at: http://localhost:5006/#/experiments/2/runs/31c483c94ed54123abae86ce85dd7394
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 223 at: http://localhost:5006/#/experiments/2/runs/bd0d9f21da024dfcaf5450a4773567a1
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 224 at: http://localhost:5006/#/experiments/2/runs/4b181b44cde0452c911f3a9fdc40b518
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 225 at: http://localhost:5006/#/experiments/2/runs/d6846f075571405fadda3a56e3b7d623
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 226 at: http://localhost:5006/#/experiments/2/runs/3d3e6e50d48d424cbfba16df08c34ed8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 227 at: http://localhost:5006/#/experiments/2/runs/df1b57564d614100ac663a069d9bfac0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 228 at: http://localhost:5006/#/experiments/2/runs/90ca58abc55a459188185ef12b9afb0b
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 229 at: http://localhost:5006/#/experiments/2/runs/65dd04d1762c426d8c7716b2edb1ce75
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 230 at: http://localhost:5006/#/experiments/2/runs/4acab1eb98f04aea96c44a6a6021dd51
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 231 at: http://localhost:5006/#/experiments/2/runs/cc4172ab769c4a9e9289a7c39708f4a3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 232 at: http://localhost:5006/#/experiments/2/runs/4a88af6ed3a240ca86a8e5d7646a4de6
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 233 at: http://localhost:5006/#/experiments/2/runs/f18465e43208440b9374ff520b95d48f
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 234 at: http://localhost:5006/#/experiments/2/runs/ced374e5fb704378a2d475c4ce5697ea
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 235 at: http://localhost:5006/#/experiments/2/runs/8fb6fb4b89f44342a4698f01d4bf7976
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 236 at: http://localhost:5006/#/experiments/2/runs/77ac0288fb1d4028bf6a9b55370c47d8
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 237 at: http://localhost:5006/#/experiments/2/runs/36822ec23ed64547b5422cc21beec214
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 238 at: http://localhost:5006/#/experiments/2/runs/9e825692dc0b421082822a84eff5161c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 239 at: http://localhost:5006/#/experiments/2/runs/5233ada98c5546ce94b6c8837f6abaf5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 240 at: http://localhost:5006/#/experiments/2/runs/abd384e1da65421ba10c3c2b493e6f01
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 241 at: http://localhost:5006/#/experiments/2/runs/d3a6db0e64d442a1a2c29e09543098d5
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 242 at: http://localhost:5006/#/experiments/2/runs/bba012718d0141f08bc2522f21f6287d
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 243 at: http://localhost:5006/#/experiments/2/runs/6c18c7bfdd2246bbb18603432904ecff
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 244 at: http://localhost:5006/#/experiments/2/runs/455ca0608d374c938f093aac665250b4
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 245 at: http://localhost:5006/#/experiments/2/runs/712593851eaf43b4afd73efc23e4732c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 246 at: http://localhost:5006/#/experiments/2/runs/eb86e9135f0b471c81d12d3625873c1c
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 247 at: http://localhost:5006/#/experiments/2/runs/3a42d28793d84a8cab106d8d8b2884eb
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 248 at: http://localhost:5006/#/experiments/2/runs/a9704cfc9a674189a3c6fe50ee7fa5f0
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# 🏃 View run Trial: 249 at: http://localhost:5006/#/experiments/2/runs/e720b5ba66754f1fa78aef19e9841006
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# Successfully registered model 'spotify_model_dev'.
# 2024/12/11 13:52:55 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: spotify_model_dev, version 1
# Modelo registrado en MLFlow: s3://mlflow/2/5f60505c605545df9615297df96c03a3/artifacts/model
# 🏃 View run best_hyperparam_2024/12/11-13:52:24" at: http://localhost:5006/#/experiments/2/runs/5f60505c605545df9615297df96c03a3
# 🧪 View experiment at: http://localhost:5006/#/experiments/2
# Created version '1' of model 'spotify_model_dev'.

# %% [markdown]
# ## Testeando el modelo
#
# Una vez que el modelo fue entrenado, podemos levantarlo y testearlo de una forma agnóstica a donde está guardado.

# %%
loaded = mlflow.sklearn.load_model(model_uri)
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import numpy as np

test_data = [0.6, 0.8, 0.7, 0.9]  # speechiness, energy, danceability, y otra característica

prediction = loaded.predict(np.array(test_data).reshape([1, -1]))

print("Predicción:", prediction)

# %%
import numpy as np

test_data = [0.088, 0.73, 0.919, 0.189]  # speechiness, energy, danceability, y otra característica

prediction = loaded.predict(np.array(test_data).reshape([1, -1]))

print("Predicción:", prediction)

# %%
import numpy as np
#dato valido
test_data = [0.0444, 0.521, 0.514, 0.143]  # speechiness, energy, danceability, valence

test_data_np = np.array(test_data).reshape([1, -1])

# Predicción
prediction = loaded.predict(test_data_np)

print("Predicción:", prediction)  # Debería salir [1] si el modelo clasifica correctamente.

# %% [markdown]
# ## Registramos el modelo
#
# Realizamos el registro del modelo en MLflow. En este registro se pone el modelo productivo que luego se usará para servir en formato on-line.

# %%
from mlflow import MlflowClient

client = MlflowClient()
name = "spotify_model_prod"
desc = "Spotify Song Preference Prediction"

# Verificar si el modelo ya existe
try:
    client.get_registered_model(name=name)
    print(f"El modelo '{name}' ya está registrado.")
except Exception as e:
    # Si el modelo no existe, lo creamos
    print(f"El modelo '{name}' no existe, creando uno nuevo...")
    client.create_registered_model(name=name, description=desc)

# Guardamos los parámetros del modelo
tags = model.get_params()
tags["model"] = type(model).__name__
tags["f1-score"] = f1_score

# Guardamos la versión del modelo
result = client.create_model_version(
    name=name,
    source=model_uri,
    run_id=model_uri.split("/")[-3],
    tags=tags
)

# Asignamos un alias (como "champion") para la nueva versión
client.set_registered_model_alias(name, "champion", version=result.version)
print(f"Modelo '{name}' registrado y alias 'champion' asignado a la versión {result.version}.")
# Out:
# 2024/12/11 13:53:46 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: spotify_model_prod, version 1
# El modelo 'spotify_model_prod' no existe, creando uno nuevo...
# Modelo 'spotify_model_prod' registrado y alias 'champion' asignado a la versión 1.

# %%
local_path = "./descargado_modelo"
mlflow.artifacts.download_artifacts(artifact_uri=model_uri, dst_path=local_path)

# %%
import boto3
import json

# Inicializa el cliente S3
s3 = boto3.client('s3')

# Especifica el bucket y la clave del archivo JSON
bucket_name = 'data'
json_key = 'data_info/data.json'

# Ruta donde se guardará el archivo descargado localmente
local_file_path = 'data_info_local.json'

try:
    # Verifica si el archivo existe en el bucket
    s3.head_object(Bucket=bucket_name, Key=json_key)
    print(f"El archivo '{json_key}' existe en el bucket '{bucket_name}'. Descargando...")

    # Descarga el archivo JSON desde S3
    result_s3 = s3.get_object(Bucket=bucket_name, Key=json_key)
    text_s3 = result_s3["Body"].read().decode()  # Decodifica el contenido a texto
    
    # Guarda el contenido en un archivo local
    with open(local_file_path, 'w') as local_file:
        local_file.write(text_s3)
    print(f"Archivo descargado y guardado localmente como: {local_file_path}")

except s3.exceptions.NoSuchKey:
    print(f"El archivo '{json_key}' no existe en el bucket '{bucket_name}'.")
except Exception as e:
    print(f"Error al descargar o guardar el archivo JSON: {str(e)}")
